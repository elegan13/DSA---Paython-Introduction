# %% [markdown]
# # **Pre Test DSA**
# ## **Churned Customers**
# Description : This script is going to show you how to learn Python from the beginning.
# <br> Author : Elias Dani L
# <br> Date   : 06 October 2019
# <br> Source : [OpenML](https://www.openml.org/d/40701)
# <br> File   : churn.csv

# %% [markdown]
# ***

# %%
#Import Package Pandas
import pandas as pd
#Import Package Numpy
import numpy as np
#Import Package Statistics
import statistics as st

# %%
#Import file csv taken from OpenML
#file name: churn.csv store in folder dataset
churn = pd.read_csv('dataset/churn.csv')
churn.head()
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# ...

# %% [markdown]
# ***

# %% [markdown]
# # 1. Is there are NaN value in dataset file churn.csv and How Statistic view each columns

# %%
#3. How many NaN value in dataset for each columns? 
df_review.isnull().sum()
churn.isnull().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# phone_number                     0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# class                            0
# dtype: int64

# %%
churn.describe()
# Out:
#             state  account_length    area_code  phone_number  \
# count  5000.00000      5000.00000  5000.000000   5000.000000
# mean     25.99840       100.25860   436.911400   2499.500000
# std      14.80348        39.69456    42.209182   1443.520003
# min       0.00000         1.00000   408.000000      0.000000
# 25%      13.00000        73.00000   408.000000   1249.750000
# 50%      26.00000       100.00000   415.000000   2499.500000
# 75%      39.00000       127.00000   415.000000   3749.250000
# max      50.00000       243.00000   510.000000   4999.000000
#
#        international_plan  voice_mail_plan  number_vmail_messages  \
# count         5000.000000      5000.000000            5000.000000
# mean             0.094600         0.264600               7.755200
# std              0.292691         0.441164              13.546393
# min              0.000000         0.000000               0.000000
# 25%              0.000000         0.000000               0.000000
# ...

# %% [markdown]
# ***

# %% [markdown]
# # 2. How Much Does The Customer Spend in a Month on Average ?

# %%
total_charge = churn.groupby(['area_code'])['total_eve_charge'].sum()
total_phone = churn.groupby(['area_code'])['phone_number'].sum()
print(total_charge)
print(total_phone)
# Out:
# area_code
# 408    21515.36
# 415    42435.43
# 510    21320.82
# Name: total_eve_charge, dtype: float64
# area_code
# 408    3166968
# 415    6252021
# 510    3078511
# Name: phone_number, dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# # 3. How Many Days in a Month , on Average, does the customer make transactions ?

# %% [markdown]
# ***

# %% [markdown]
# # 4. How Long ago was the customer's last purchase (days) ?

# %% [markdown]
# ***

# %% [markdown]
# # 5. How Matrix Customer Segmentation  ?
